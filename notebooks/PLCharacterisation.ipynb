# %%
# Python Libs
import cv2
import numpy as np
import matplotlib.pyplot as plt
import ctypes
import copy
from IPython.display import display, clear_output
import ipywidgets
import time
import scipy.io
from scipy import io, integrate, linalg, signal
from scipy.io import savemat, loadmat
from scipy.fft import fft, fftfreq, fftshift,ifftshift, fft2,ifft2,rfft2,irfft2
# Defult Pploting properties 
plt.style.use('dark_background')
plt.rcParams['figure.figsize'] = [2,2]

#General libs
import JazLabs.utils.PlotingFunctions.ComplexPlotFunction as cmplxplt

import JazLabs.hardware.Cameras.FirstlightCameras.FirstLightCred3_2Lite as CamLib
import JazLabs.hardware.Cameras.Camera_Client as CamClientlib
import JazLabs.hardware.Cameras.Camera_Server as CamServerlib 
import JazLabs.hardware.Cameras.Camera_Viewer as CamViewerlib 

import JazLabs.hardware.Lasers.Anritsu as LaserLib

import JazLabs.hardware.digHolo.digHolo_pylibs.digHoloWindowThread as digholoObjThread
import JazLabs.hardware.digHolo.digHolo_pylibs.digholoObject as digholoObj
import JazLabs.utils.AlignmentRoutines_digholo as AlignRouts_digholo
import JazLabs.utils.AlignmentRoutines_MotorisedStage_Camera as AlignRouts_Stage_Camera


import JazLabs.hardware.MotorisedStages.Luminos.LuminosStage as LuminosStageLib
import JazLabs.hardware.MotorisedStages.Luminos.LuminosStage_widget as LuminosStageLibwidget
import JazLabs.hardware.MotorisedStages.Newport.NewportMounts as NewportStageLib
import JazLabs.hardware.MotorisedStages.Newport.NewportMounts_widget as NewportStageWidget







#Optical Power Attenuator
# import Lab_Equipment.OpticalPowerAttenuator.OpticalPowerAttenuator as OPALib
# import Lab_Equipment.DAC.DAC_controllerThread as VoltageController



#Camera Libs
import Lab_Equipment.Camera.CameraObject as CamForm
import Lab_Equipment.Camera.Camera_widget as CamWidget
import Lab_Equipment.Camera.FirstLightCameraObj as FLForm
import Lab_Equipment.Camera.LucidVisionCameraObj as LucidVisForm


# digiHolo Libs
import Lab_Equipment.digHolo.digHolo_pylibs.digiholoWindowThread as digholoObjThread
import Lab_Equipment.digHolo.digHolo_pylibs.digholoObject as digholoObj

#ALignment and Calibration Libs
import Lab_Equipment.AlignmentRoutines.AlignmentRoutines_digholo as AlignRouts_digholo
# import Lab_Equipment.AlignmentRoutines.AlignmentRoutines_SLM_Cam as AlignRouts_SLM_Cam
# import Lab_Equipment.AlignmentRoutines.AlignmentRoutines_SLM_PowerMeter as AlignRouts_SLM_PwrMeter
import Lab_Equipment.AlignmentRoutines.AlignmentRoutines_MotorisedStage_Camera as AlignRouts_Stage_Camera

# import Lab_Equipment.AlignmentRoutines.TimeCalibration_SLM as slmTimeCal

import Lab_Equipment.MotorisedStage.LuminosStage as LuminosStageLib
import Lab_Equipment.MotorisedStage.LuminosStage_widget as LuminosStageLibwidget
import Lab_Equipment.MotorisedStage.NewportMounts as NewportStageLib



# import Lab_Equipment.AlignmentRoutines.PhaseCalibration_SLM_digholo as PhaseCal

# import Lab_Equipment.AlignmentRoutines.OPA_Calibration as OPACalLib


import Lab_Equipment.Laser.JDSUniphaseTunableLaser as Laserlib
import Lab_Equipment.Laser.JDSLaser_widget as laserwidget
import Lab_Equipment.OpticalSwitch.JDSUniphaseOpticalSwitch as OpticalSwitchLib
import Lab_Equipment.OpticalSwitch.OpticalSwitch_widget as OpticalSwitchWidget



#MEasurement Routine lib
import Lab_Equipment.Measurements.MeasurementRoutines as MeasureLib
