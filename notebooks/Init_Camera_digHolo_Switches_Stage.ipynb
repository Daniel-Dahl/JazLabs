# %% [markdown]
# # Launch Servers, Clients, and Widgets
#
# This notebook launches:
# - Camera server/client/widget (First Light C-Red3_2Lite)
# - digiHolo viewer
# - Optical switch server/client/widget
# - Pol switch server/client/widget
# - Luminos stage server/client/widget

# %%
# -----------------------------
# Edit these for your hardware
# -----------------------------
CAMERA_TYPE = "First Light C-Red3_2Lite"
CAMERA_KWARGS = {"CameraIdx": 0, "CalibrationFile": None}
CAM_HOST = "127.0.0.1"
CAM_COMMAND_PORT = 50731
CAM_FRAME_PUB_PORT = 50732

OPT_SWITCH_PORT = "COM12"
OPT_SWITCH_HOST = "127.0.0.1"
OPT_SWITCH_COMMAND_PORT = 50831

POL_SWITCH_PORT = "COM4"
POL_SWITCH_HOST = "127.0.0.1"
POL_SWITCH_COMMAND_PORT = 50841

LUMINOS_STAGE_PORT = "COM5"
STAGE_HOST = "127.0.0.1"
STAGE_COMMAND_PORT = 50931

# %%
from JazLabs.hardware.Cameras.Camera_Server import CameraZMQServer
from JazLabs.hardware.Cameras.Camera_Client import CameraClient
from JazLabs.hardware.Cameras.Camera_Widget import launch_camera_widget
import JazLabs.hardware.Cameras.Camera_Viewer as CamViewerlib


from JazLabs.hardware.digHolo.digHolo_pylibs.digHolo_Veiwer import digholoWindow

import JazLabs.hardware.Lasers.Anritsu.AnritsuMG963xLaser as Laserlib

from JazLabs.hardware.OpticalSwitch.OpticalSwitch_Server import OpticalSwitchZMQServer
from JazLabs.hardware.OpticalSwitch.OpticalSwitch_Client import OpticalSwitchClient
from JazLabs.hardware.OpticalSwitch.OpticalSwitch_widget import launch_optical_switch_widget_process

from JazLabs.hardware.MotorisedStages.MotorisedStage_Server import MotorisedStageZMQServer
from JazLabs.hardware.MotorisedStages.MotorisedStage_Client import MotorisedStageClient
from JazLabs.hardware.MotorisedStages.MotorisedStage_Widget import launch_motorised_stage_widget_process

# %%
InitaliseLaser=1
if InitaliseLaser==1:
    # Laser=Laserlib.LaserObject_JDSUniphaseTunableLaser(LaserID="GPIB0::1::INSTR")
    Laser=Laserlib.LaserObject(port="COM3")

else:
    del Laser

# %%
camera_server = CameraZMQServer(
    host=CAM_HOST,
    command_port=CAM_COMMAND_PORT,
    frame_pub_port=CAM_FRAME_PUB_PORT,
    CameraType=CAMERA_TYPE,
    CameraKwargs=CAMERA_KWARGS,
)
camera_server.startProcess()

camera_client = CameraClient(
    host=CAM_HOST,
    command_port=CAM_COMMAND_PORT,
    frame_pub_port=CAM_FRAME_PUB_PORT,
    client_id="nb_camera_client",
)
viewer = CamViewerlib.CameraViewer(
    host=CAM_HOST,
    command_port=CAM_COMMAND_PORT,
    frame_pub_port=CAM_FRAME_PUB_PORT,
    initial_scale=1,
)
viewer.startProcess()

camera_widget = launch_camera_widget(
    host=CAM_HOST,
    command_port=CAM_COMMAND_PORT,
    frame_pub_port=CAM_FRAME_PUB_PORT,
)

print("Camera server/client/widget launched")
# Out:
# Camera server process started with PID 20484
# Camera viewer started with PID 4680
# Camera widget started with PID 14680
# Camera server/client/widget launched

# %%
digholo_viewer = digholoWindow(
    host=CAM_HOST,
    command_port=CAM_COMMAND_PORT,
    frame_pub_port=CAM_FRAME_PUB_PORT,
)
print("digiHolo viewer initialised")
# Out:
# digiHolo viewer initialised

# %%
opt_switch_server = OpticalSwitchZMQServer(
    host=OPT_SWITCH_HOST,
    command_port=OPT_SWITCH_COMMAND_PORT,
    switch_type="JDS_SC",
    switch_kwargs={"port": OPT_SWITCH_PORT},
)
opt_switch_server.startProcess()

opt_switch_client = OpticalSwitchClient(
    host=OPT_SWITCH_HOST,
    command_port=OPT_SWITCH_COMMAND_PORT,
    client_id="nb_opt_switch_client",
)

opt_switch_widget_proc = launch_optical_switch_widget_process(
    host=OPT_SWITCH_HOST,
    command_port=OPT_SWITCH_COMMAND_PORT,
)

print("Optical switch server/client/widget launched")
# Out:
# Optical switch server process started with PID 14004
# Optical switch server/client/widget launched

# %%
# Pol switch uses the same switch server/client/widget stack, on a separate command port
pol_switch_server = OpticalSwitchZMQServer(
    host=POL_SWITCH_HOST,
    command_port=POL_SWITCH_COMMAND_PORT,
    switch_type="JDS_Pol",
    switch_kwargs={"port": POL_SWITCH_PORT},
)
pol_switch_server.startProcess()

pol_switch_client = OpticalSwitchClient(
    host=POL_SWITCH_HOST,
    command_port=POL_SWITCH_COMMAND_PORT,
    client_id="nb_pol_switch_client",
)

pol_switch_widget_proc = launch_optical_switch_widget_process(
    host=POL_SWITCH_HOST,
    command_port=POL_SWITCH_COMMAND_PORT,
)

print("Pol switch server/client/widget launched")
# Out:
# Optical switch server process started with PID 4124
# Pol switch server/client/widget launched

# %%
stage_server = MotorisedStageZMQServer(
    host=STAGE_HOST,
    command_port=STAGE_COMMAND_PORT,
    stage_type="Luminos",
    stage_kwargs={"port": LUMINOS_STAGE_PORT},
)
stage_server.startProcess()

stage_client = MotorisedStageClient(
    host=STAGE_HOST,
    command_port=STAGE_COMMAND_PORT,
    client_id="nb_stage_client",
)

stage_widget_proc = launch_motorised_stage_widget_process(
    host=STAGE_HOST,
    command_port=STAGE_COMMAND_PORT,
)

print("Luminos stage server/client/widget launched")
# Out:
# Motorised stage server process started with PID 18296
# Luminos stage server/client/widget launched

# %%
print("Camera properties:", camera_client.GetProperties())
# Out:
# ---------------------------------------------------------------------------
# ZMQError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print("Camera properties:", camera_client.GetProperties())
#
# File ~\Documents\PL_Characterisation\JazLabs\src\JazLabs\hardware\Cameras\Camera_Client.py:230, in CameraClient.GetProperties(self)
#     229 def GetProperties(self):
# --> 230     return self.SendCommand({"cmd": "get_properties"})
#
# File ~\Documents\PL_Characterisation\JazLabs\src\JazLabs\hardware\Cameras\Camera_Client.py:77, in CameraClient.SendCommand(self, msg)
#      74 def SendCommand(self, msg):
#      75     msg["client_id"] = self.client_id
# ---> 77     self.socket.send_json(msg)
#      78     reply = self.socket.recv_json()
#      80     if not reply.get("ok", False):
#
# File c:\ProgramData\anaconda3\envs\py311\Lib\site-packages\zmq\sugar\socket.py:1009, in Socket.send_json(self, obj, flags, **kwargs)
#    1007         send_kwargs[key] = kwargs.pop(key)
#    1008 msg = jsonapi.dumps(obj, **kwargs)
# -> 1009 return self.send(msg, flags=flags, **send_kwargs)
#
# File c:\ProgramData\anaconda3\envs\py311\Lib\site-packages\zmq\sugar\socket.py:698, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     691         data = zmq.Frame(
#     692             data,
#     693             track=track,
#     694             copy=copy or None,
#     695             copy_threshold=self.copy_threshold,
#     696         )
#     697     data.group = group
# --> 698 return super().send(data, flags=flags, copy=copy, track=track)
#
# File c:\ProgramData\anaconda3\envs\py311\Lib\site-packages\zmq\backend\cython\_zmq.py:1152, in zmq.backend.cython._zmq.Socket.send()
#
# File c:\ProgramData\anaconda3\envs\py311\Lib\site-packages\zmq\backend\cython\_zmq.py:1200, in zmq.backend.cython._zmq.Socket.send()
#
# File c:\ProgramData\anaconda3\envs\py311\Lib\site-packages\zmq\backend\cython\_zmq.py:1473, in zmq.backend.cython._zmq._send_copy()
#
# File c:\ProgramData\anaconda3\envs\py311\Lib\site-packages\zmq\backend\cython\_zmq.py:1468, in zmq.backend.cython._zmq._send_copy()
#
# File c:\ProgramData\anaconda3\envs\py311\Lib\site-packages\zmq\backend\cython\_zmq.py:190, in zmq.backend.cython._zmq._check_rc()
#
# ZMQError: Operation cannot be accomplished in current state

# %%
# print("Camera properties:", camera_client.GetProperties())
print("Optical switch properties:", opt_switch_client.GetProperties())
print("Pol switch properties:", pol_switch_client.GetProperties())
print("Stage properties:", stage_client.GetProperties())
print("Stage positions:", stage_client.GetPositions())
# Out:
# Optical switch properties: {'switch_type': 'JDS_SC', 'command_port': 50831, 'host': '127.0.0.1'}
# Pol switch properties: {'switch_type': 'JDS_Pol', 'command_port': 50841, 'host': '127.0.0.1'}
# Stage properties: {'stage_type': 'Luminos', 'command_port': 50931, 'host': '127.0.0.1'}
# Stage positions: [128000.0, 64000.0, 64000.0, 57600.0, 30236.0, 30236.0]

# %%
print("Optical switch properties:", opt_switch_client.GetProperties())
# Out:
# Optical switch properties: {'switch_type': 'JDS_SC', 'command_port': 50831, 'host': '127.0.0.1'}

# %%
stage_client.MoveAbs(axis="Z",value=128000)

# %%
import numpy as np

# %%
# GetBatchOfFrames(self,SLMObjIdx=0,pol='H',CamObjIdx=[0],slmChannel=None,modeCount=None,AvgFrameCount=1,modeIdxArr=None):
AvgFrameCount=1  
modeCount=6
wavelengthCount=40
wavelenMin=1520e-9
wavelenMax=1600e-9
# Laser.set_power_mw(0.5)
Wavelengths=np.linspace(wavelenMin,wavelenMax,wavelengthCount)    
    

frames_wavelengths_modes=np.empty((wavelengthCount,modeCount*AvgFrameCount,Cam.CamObject.FrameHeight.value,Cam.CamObject.FrameWidth.value),dtype=np.float32)
# frames_wavelengths_modes_superposition=np.empty((wavelengthCount,modeCount*AvgFrameCount,Cam.CamObject.FrameHeight.value,Cam.CamObject.FrameWidth.value),dtype=np.float32)
# frame_wavelength_NoRef=np.empty((wavelengthCount,modeCount*AvgFrameCount,Cam.CamObject.FrameHeight.value,Cam.CamObject.FrameWidth.value),dtype=np.float32)
imodeStart=1
iframe=0
Cam.CamObject.SetSingleFrameCapMode()
for iwave in range(wavelengthCount):
    Laser.set_wavelength_nm(Wavelengths[iwave]*1e9)
    time.sleep(2)
    iframe =0
    for imode in range(modeCount):
        ichan=imode+imodeStart
        OpticalSwitch.set_channel(ichan)
        for iavg in range(AvgFrameCount):
            frames_wavelengths_modes[iwave,iframe,:,:]=Cam.CamObject.GetFrame(ConvertToFloat32=True)
            iframe+=1
Cam.CamObject.SetContinousFrameCapMode()
